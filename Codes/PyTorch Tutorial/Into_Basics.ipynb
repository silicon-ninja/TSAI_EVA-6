# %%
import torch 
import numpy as np 
#inside the arg we can specify the dimension(dimension)
x = torch.empty(3) # produces empty numbers inside the matrix
print(x) 
y = torch.rand(3,3) # produces random numbers inside the matrix
print(y)
z = torch.zeros(3) # fills zeros inside the matrix
print(z)
a = torch.ones (3)# fills ones inside the matrix
print(a)
b = torch.tensor([2.5,2.5]) # creating a custom tensor matrix

y.view(2) # resizing the tensors to a oneD Matrix
print(y)

a = torch.ones(5)
print(a)
b = a.numpy()
print(b)

# Quick Notes
# 1. To specify the data type of the tensor we can use dtype = torch.int,float,double
# 2. If the function contains "_" at the end it ccompiles as in-place result.
# 3. [:,1] Slicing works as well here in Pytorch.
# Out:
# tensor([[[[ 0.0000e+00,  0.0000e+00,  0.0000e+00],
#           [ 0.0000e+00,  0.0000e+00,  0.0000e+00],
#           [ 0.0000e+00,  0.0000e+00,  3.5733e-43]],
#
#          [[ 0.0000e+00,  4.3440e-44,  0.0000e+00],
#           [-3.9685e-34,  3.0872e-41, -3.9685e-34],
#           [ 3.0872e-41,  3.5733e-43,  0.0000e+00]],
#
#          [[ 5.7453e-44,  0.0000e+00, -3.9685e-34],
#           [ 3.0872e-41, -3.9685e-34,  3.0872e-41],
#           [ 3.5733e-43,  0.0000e+00,  0.0000e+00]]],
#
#
#         [[[ 0.0000e+00,  0.0000e+00,  0.0000e+00],
#           [ 0.0000e+00,  0.0000e+00,  3.5733e-43],
#           [ 0.0000e+00,  1.4013e-45,  0.0000e+00]],
#
#          [[-3.9685e-34,  3.0872e-41, -3.9685e-34],
#           [ 3.0872e-41,  3.5733e-43,  0.0000e+00],
#           [ 6.7262e-44,  0.0000e+00, -3.9685e-34]],
#
#          [[ 3.0872e-41, -3.9685e-34,  3.0872e-41],
#           [ 3.5733e-43,  0.0000e+00,  0.0000e+00],
#           [ 0.0000e+00,  0.0000e+00,  0.0000e+00]]],
#
#
# ...
